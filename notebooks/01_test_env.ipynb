# %%
import pandas as pd
import numpy as np
import sys

# 把外层文件夹加入系统路径，这样就能读取到 src 里的代码了
sys.path.append('../') 
from src.utils import calculate_average

# 测试我们的函数
my_numbers = [10, 20, 30, 40, 50]
avg = calculate_average(my_numbers)

print(f"计算出的平均值是: {avg}")
print(f"Pandas 版本: {pd.__version__}")
print(f"Numpy 版本: {np.__version__}")
# Out:
# 计算出的平均值是: 30.0
# Pandas 版本: 3.0.5
# Numpy 版本: 2.5.2

# %%
import pandas as pd
import numpy as np
import sys

sys.path.append('../') 
from src.utils import calculate_average

np.random.seed(88) 
dates = pd.date_range(start="2026-08-10", periods=5, freq="B")
sse_index = np.array([2950.5, 2962.1, 2945.3, 2970.8, 2985.0])
volume_100m = np.array([3200, 3450, 3100, 3600, 3800])

df = pd.DataFrame({
    "date": dates,
    "sse_index": sse_index,
    "volume_100m": volume_100m
})

display(df) 

sse_list = df["sse_index"].tolist()
avg_sse = calculate_average(sse_list)

print(f"avg: {avg_sse}")
# Out:
# utils.py 模块加载成功！
#         date  sse_index  volume_100m
# 0 2026-08-10     2950.5         3200
# 1 2026-08-11     2962.1         3450
# 2 2026-08-12     2945.3         3100
# 3 2026-08-13     2970.8         3600
# 4 2026-08-14     2985.0         3800
# avg: 2962.7400000000002

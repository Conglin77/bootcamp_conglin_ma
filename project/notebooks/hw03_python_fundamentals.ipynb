# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import sys
import os

np.random.seed(42)
arr = np.random.rand(1000000)

t0 = time.time()
res1 = [x * 2 for x in arr]
t_loop = time.time() - t0

t0 = time.time()
res2 = arr * 2
t_vec = time.time() - t0

print(f"Loop time: {t_loop:.5f}s")
print(f"Vectorized time: {t_vec:.5f}s")
print(f"Difference: {t_loop/t_vec:.1f}x\n")

df = pd.read_csv('../data/raw/starter_data.csv')
df.info()
display(df.head())

sys.path.append('../')
from src.utils import get_summary_stats

summary_df, grouped_df = get_summary_stats(df)
display(summary_df)

if not grouped_df.empty:
    display(grouped_df)

os.makedirs('../data/processed', exist_ok=True)
summary_df.to_csv('../data/processed/summary.csv')

numeric_cols = df.select_dtypes(include=[np.number]).columns
if len(numeric_cols) > 0:
    col = numeric_cols[0]
    df[col].plot(kind='hist', title=f'{col} Distribution', color='skyblue', edgecolor='black')
    plt.xlabel(col)
    plt.savefig('../data/processed/basic_plot.png')
    plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Loop time: 0.05006s
# Vectorized time: 0.00090s
# Difference: 55.8x
#
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  10 non-null     str
#  1   value     10 non-null     int64
#  2   date      10 non-null     str
# dtypes: int64(1), str(2)
# memory usage: 372.0 bytes
#   category  value        date
# 0        A     10  2025-08-01
# 1        B     15  2025-08-02
# 2        A     12  2025-08-03
# 3        B     18  2025-08-04
# 4        C     25  2025-08-05
# utils.py 模块加载成功！
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 28
#      24 df.info()
#      25 display(df.head())
#      26
#      27 sys.path.append('../')
# ...
